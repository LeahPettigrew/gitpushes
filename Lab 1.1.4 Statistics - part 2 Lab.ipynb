# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Statistics - part 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from numpy.random import RandomState
import scipy.stats

# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# # 1. Plot a histogram of a set of observations
#
# Experiment with various number of bins:
# ```
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""
# Out:
# 'CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH'

# %%
# plot a histogram of a set of observations
# experiment with various number of bins
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5

# %%
# ANSWER
n, bins, patches = plt.hist(x, 10, density=False, facecolor='g', alpha=0.75)

plt.grid(True)
plt.show()

# %%
n, bins, patches = plt.hist(x, 15, density=False, facecolor='b', alpha=0.5)

plt.grid(True)
plt.show()

# %% [markdown]
# # 2. Calculate statistical information of a set of observations using numpy and stats
# ```
#     # Desired Output:
#
# mean of observations = 28.884615384615383
# median of observations = 27.0
# mode of observations = ModeResult(mode=array([10]), count=array([4]))
# percentile of observations = [10.   27.   35.75]
# statistical summary of observations = DescribeResult(nobs=26, minmax=(4, 100), mean=28.884615384615383, variance=523.3061538461537, skewness=1.4001632366778733, kurtosis=2.0634808152807826)
# ```

# %%
# calculate statistical information of a set of observations using numpy and stats
observations = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100,10,32,49,10,10]

# %%
from statistics import mode
mode(observations)
# Out:
# 10

# %%
np.median(observations)
# Out:
# 27.0

# %%
np.mean(observations)
# Out:
# 28.884615384615383

# %%
stats.describe(observations)
# Out:
# DescribeResult(nobs=26, minmax=(4, 100), mean=28.884615384615383, variance=523.3061538461537, skewness=1.4001632366778733, kurtosis=2.0634808152807826)

# %%
np.percentile(observations, [25,50,75])
# Out:
# array([10.  , 27.  , 35.75])

# %% [markdown]
# # 3. Plot box chart of observations
# ```
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""
# Out:
# 'CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH'

# %%
# plot box chart of observations
observations = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100,10,32,49,10,10]

# %% [markdown]
# # 4. Create a Binomial Distribution
#
# Look at the help function for
# > stats.binom.pmf
#
# What does it do?
# ```
# # Expected Output:
# ```

# %%
plt.boxplot(observations)
plt.yscale('linear')
plt.grid(b=True, which='major', color='b', linestyle='-')
plt.grid(b=True, which='minor', color='r', linestyle='--')
plt.show()
# Out:
# C:\Users\Leah Pettigrew\AppData\Local\Temp\ipykernel_19432\352735731.py:3: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='b', linestyle='-')
# C:\Users\Leah Pettigrew\AppData\Local\Temp\ipykernel_19432\352735731.py:4: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='minor', color='r', linestyle='--')

# %%
2 outliers. most data above 10 and below 40
# Out:
#   Input In [17]
#     2 outliers. most data above 10 and below 40
#       ^
# SyntaxError: invalid syntax

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""

# %%
from scipy import stats
help(stats.binom.pmf)

# %%
# creating a Binomial Distribution
n = 10
p = 0.5
k = np.arange(0,20)

print(k)

# ANSWER
binomial = stats.binom.pmf(k,n,p)
#print('Bionmial distribution data:\n',binomial)
plt.plot(k,binomial,'o-')
plt.title('Binomial distribution: n=%i p=%.2f' %(n,p),fontsize=15)
plt.xlabel('Range')
plt.ylabel('Probability')
plt.grid()
plt.show()

# %% [markdown]
# # 5. Create a scatter plot
# ```
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50 #number of samples
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii . 30 times random numbers to the power of 2. will randomly have some big circles and some small circles

# ANSWER
plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # 6. Calculate and Visualize Correlations
#
# Lookup the help function for
# >np.corrcoef.
#
# What does it do?
# ```
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""
# Out:
# 'CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH'

# %%
import matplotlib
# Calculate and visualise correlations
np.random.seed(1)

# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Positive Correlation with some noise
y = x + np.random.normal(0, 10, 1000)

# ANSWER
print('Correlation of x and y = ',np.corrcoef(x, y))
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()
# Out:
# Correlation of x and y =  [[1.         0.81543901]
#  [0.81543901 1.        ]]

# %% [markdown]
# # 7. [BONUS] Plot X, Y and Best Fit Line
#
# **Write a function to calculate best fit.**
#
# ![alt text](https://i.imgur.com/B43vOV0.jpg)
#
# [Least Squares Regression (Best Line Fit)]: https://www.mathsisfun.com/data/least-squares-regression.html "Least Squares Regression"
#
# ```
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""
# Out:
# 'CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH'

# %%
# Calculate the coefficient of best fit line or curve
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100,10,32,49,10,10]
y = [88,12,23,3,6,8,9,12,27,36,34,77,60,35,36,37,18,49,50,100,10,32,49,10,10,22]

print(np.polyfit(x,y,1)) #the intercept and slope
# Out:
# [ 0.11163049 29.5832885 ]

# %%
# sample points 
X = [0, 5, 10, 15, 20]
Y = [0, 7, 10, 13, 20]

# solve for a and b
def best_fit(X, Y):

    xbar = sum(X)/len(X)
    ybar = sum(Y)/len(Y)
    n = len(X) # or len(Y)

    numer = sum([xi*yi for xi,yi in zip(X, Y)]) - n * xbar * ybar
    denum = sum([xi**2 for xi in X]) - n * xbar**2

    b = numer / denum
    a = ybar - b * xbar

    print('best fit line:\ny = {:.2f} + {:.2f}x'.format(a, b))

    return a, b

# solution
a, b = best_fit(X, Y) #intercept and slope
#best fit line:
#y = 0.80 + 0.92x

# plot points and fit line
import matplotlib.pyplot as plt
plt.scatter(X, Y)
yfit = [a + b * xi for xi in X]
plt.plot(X, yfit)
# Out:
# best fit line:
# y = 0.80 + 0.92x

# %% [markdown]
# # 8. plot a histogram of a set of observations - centered
#
# Experiment with various number of bins. Set y as:
# ```
#         y = x - np.mean(x)
#
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""
# Out:
# 'CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH'

# %%
# plot a histogram of a set of observations - centered
# experiment with various number of bins
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
# ANSWER

# %% [markdown]
# # 9. plot a histogram of a set of observations - scaled
#
# Set y as:
# ```
#         y = x / np.std(x)
#
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""
# Out:
# 'CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH'

# %%
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
y = x - np.mean(x)
print('x:',x)
print('y:',y)
num_bins = 5
n, bins, patches = plt.hist(y, num_bins, facecolor='blue', alpha=0.5)
plt.show()
# Out:
# x: [21, 22, 23, 4, 5, 6, 77, 8, 9, 10, 31, 32, 33, 34, 35, 36, 37, 18, 49, 50, 100]
# y: [ -9.47619048  -8.47619048  -7.47619048 -26.47619048 -25.47619048
#  -24.47619048  46.52380952 -22.47619048 -21.47619048 -20.47619048
#    0.52380952   1.52380952   2.52380952   3.52380952   4.52380952
#    5.52380952   6.52380952 -12.47619048  18.52380952  19.52380952
#   69.52380952]

# %%
# plot a histogram of a set of observations - scaled
# experiment with various number of bins 
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]


# ANSWER
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
y = x / np.std(x)
print('x:',x)
print('y:',y)
num_bins = 5
n, bins, patches = plt.hist(y, num_bins, facecolor='blue', alpha=0.5)
plt.show()
# Out:
# x: [21, 22, 23, 4, 5, 6, 77, 8, 9, 10, 31, 32, 33, 34, 35, 36, 37, 18, 49, 50, 100]
# y: [0.89562766 0.93827659 0.98092553 0.17059574 0.21324468 0.25589362
#  3.28396807 0.34119149 0.38384042 0.42648936 1.32211701 1.36476595
#  1.40741489 1.45006382 1.49271276 1.53536169 1.57801063 0.76768085
#  2.08979786 2.1324468  4.2648936 ]

# %% [markdown]
# # 10. [BONUS] Create a probplot against normal distribution
#
# Check following methods:
#
# 1. stats.loggamma.rvs
# 2. stats.probplot
# 3. stats.norm
# 4. stats.boxcox
#
# ```
# # Expected Output:
# ```

# %%
"""CODE DELETED. DO NOT TOUCH THIS TEXT. RUNNING THIS CELL WITH SHIFT-ENTER WILL DELETE THE GRAPH"""

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
x = stats.loggamma.rvs(5, size=500) + 5

# ANSWER

# %%
from scipy import stats
import matplotlib.pyplot as plt
fig = plt.figure()
ax1 = fig.add_subplot(211)
x = stats.loggamma.rvs(5, size=500) + 5
prob = stats.probplot(x, dist=stats.norm, plot=ax1)
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')
ax2 = fig.add_subplot(212)
xt, _ = stats.boxcox(x)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Box-Cox transformation')
plt.show()

# %% [markdown]
# # 11. [BONUS] Calculate Mean Confidence Interval
#
# Check following methods:
#
# 1. scipy.stats.sem
# 2. scipy.stats.t.ppf
#
# ```
# # Expected Output:
# (30.476190476190474, 19.539561081583383, 41.41281987079756)
# ```

# %%
import numpy as np
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

data = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
print(mean_confidence_interval(data))
# Out:
# (30.476190476190474, 19.539561081583383, 41.41281987079756)

# %%
results = stats.ttest_1samp(data,170.0)
print(results)
# Out:
# Ttest_1sampResult(statistic=-26.611632907069318, pvalue=4.359219197358204e-17)

# %%
import scipy
scipy.__version__
# Out:
# '1.7.3'

# %%
rng = np.random.default_rng()
rvs = stats.norm.rvs(loc=5, scale=10, size=(50, 2), random_state=rng)
print(rvs)
# Out:
# [[ 1.98925452e+01 -1.79822250e+00]
#  [ 8.35790303e+00 -3.48302416e+00]
#  [-5.87764245e+00  8.34734947e+00]
#  [ 8.90421668e+00  9.70306135e+00]
#  [ 1.60414640e+01  7.13528136e-01]
#  [ 2.19234162e+01  1.55473750e+01]
#  [ 1.98518463e+01  2.63266502e-02]
#  [ 2.04265930e+01  1.00275950e+01]
#  [ 8.61773455e+00  1.06495351e+01]
#  [ 5.08333758e+00 -9.41146442e+00]
#  [ 5.79774567e+00  8.89395218e+00]
#  [ 1.11244792e+01  1.05949729e+01]
#  [-6.64147824e+00 -1.62481719e+01]
#  [ 3.56990864e-01 -1.46420381e+00]
#  [ 6.78978618e+00 -9.98953881e-01]
#  [ 1.60508918e+01  1.12055998e+01]
#  [ 7.47613321e+00  3.91858167e+00]
#  [ 2.65333689e+01  9.70165183e+00]
#  [-9.53280328e+00  1.03499062e+01]
#  [ 1.08436620e+01 -2.13528147e+00]
#  [ 3.52781980e+01  1.07166477e+01]
#  [-1.06472288e+01 -1.13194473e+01]
#  [ 2.78966225e+01  2.71310519e+01]
#  [ 1.14110994e+01  6.77273280e+00]
#  [ 2.14496455e+01  3.57484095e+00]
#  [ 2.12537020e+01  7.87512853e+00]
#  [-2.28532022e+00  9.78085806e+00]
#  [ 5.01530825e-02  4.07326852e+00]
#  [-4.09964527e+00  2.17859846e+01]
#  [ 8.66301313e+00  1.77743690e+01]
#  [ 7.30145521e+00 -5.70572956e+00]
#  [-9.54174324e-01 -5.53408888e+00]
#  [ 1.93341051e+01  3.78093095e+00]
#  [-1.36617580e+01  3.97885569e+01]
#  [ 1.41937427e+01  5.05287064e+00]
#  [ 6.84115010e+00  8.60172416e-01]
#  [-7.13377573e-01 -9.26851303e+00]
#  [ 9.02307156e+00  1.14709008e+01]
#  [ 1.83829474e+01  2.45668676e+01]
#  [ 1.71538176e+01 -1.38267771e+01]
#  [ 4.38618021e-01  9.46397004e+00]
#  [ 3.41088448e+00 -1.09434391e+01]
#  [-5.97825340e+00 -7.45190851e+00]
#  [ 3.67815987e-01 -1.08125613e+01]
#  [ 1.56808254e+01 -6.20824268e+00]
#  [ 6.25718473e+00 -5.97924700e+00]
#  [ 3.55940903e+00  1.11155423e+01]
#  [ 1.92046583e+01  2.31476332e+00]
#  [ 1.66167797e+01  6.04909784e+00]
#  [ 1.98299973e+01  1.81536230e+01]]

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
